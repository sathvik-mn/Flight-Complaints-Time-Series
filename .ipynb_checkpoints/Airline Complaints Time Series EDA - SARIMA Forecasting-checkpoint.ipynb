# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
# %matplotlib inline

# Load specific forecasting tools
from statsmodels.tsa.statespace.sarimax import SARIMAX

#from statsmodels.graphics.tsaplots import plot_acf,plot_pacf # for determining (p,q) orders
from statsmodels.tsa.seasonal import seasonal_decompose, DecomposeResult      # for ETS Plots
# !pip install pmdarima
from pmdarima import auto_arima                              # for determining ARIMA orders

# Load specific evaluation tools
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse

# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")
# Out:
# Requirement already satisfied: pmdarima in c:\users\sathv\appdata\local\programs\python\python312\lib\site-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in c:\users\sathv\appdata\local\programs\python\python312\lib\site-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\sathv\appdata\local\programs\python\python312\lib\site-packages (from pmdarima) (3.0.10)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\sathv\appdata\local\programs\python\python312\lib\site-packages (from pmdarima) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in c:\users\sathv\appdata\local\programs\python\python312\lib\site-packages (from pmdarima) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\sathv\appdata\local\programs\python\python312\lib\site-packages (from pmdarima) (1.5.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\sathv\appdata\local\programs\python\python312\lib\site-packages (from pmdarima) (1.14.0)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\sathv\appdata\local\programs\python\python312\lib\site-packages (from pmdarima) (0.14.2)
# Requirement already satisfied: urllib3 in c:\users\sathv\appdata\local\programs\python\python312\lib\site-packages (from pmdarima) (2.2.1)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\sathv\appdata\local\programs\python\python312\lib\site-packages (from pmdarima) (71.1.0)
# Requirement already satisfied: packaging>=17.1 in c:\users\sathv\appdata\local\programs\python\python312\lib\site-packages (from pmdarima) (24.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sathv\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sathv\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sathv\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\sathv\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\sathv\appdata\local\programs\python\python312\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Requirement already satisfied: six in c:\users\sathv\appdata\local\programs\python\python312\lib\site-packages (from patsy>=0.5.6->statsmodels>=0.13.2->pmdarima) (1.16.0)

# %%
# Load the data
file_path = r"D:\Time Series\Flight Complaints\baggagecomplaints.csv"
df = pd.read_csv(file_path,index_col='Date',parse_dates=True)

# %%
df
# Out:
#                    Airline  Month  Year  Baggage  Scheduled  Cancelled  \
# Date
# 2004-01-01  American Eagle      1  2004    12502      38276       2481
# 2004-02-01  American Eagle      2  2004     8977      35762        886
# 2004-03-01  American Eagle      3  2004    10289      39445       1346
# 2004-04-01  American Eagle      4  2004     8095      38982        755
# 2004-05-01  American Eagle      5  2004    10618      40422       2206
# ...                    ...    ...   ...      ...        ...        ...
# 2010-08-01          United      8  2010    14099      30637        344
# 2010-09-01          United      9  2010     9435      28072        161
# 2010-10-01          United     10  2010     9565      29144        140
# 2010-11-01          United     11  2010     8597      27318        104
# 2010-12-01          United     12  2010    14415      27619        599
#
#             Enplaned
# Date
# 2004-01-01    992360
# 2004-02-01   1060618
# 2004-03-01   1227469
# 2004-04-01   1234451
# 2004-05-01   1267581
# ...              ...
# 2010-08-01   4263211
# 2010-09-01   3679517
# 2010-10-01   3952549
# 2010-11-01   3573268
# 2010-12-01   3493643
#
# [252 rows x 7 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of                    Airline  Month  Year  Baggage  Scheduled  Cancelled  \
# Date
# 2004-01-01  American Eagle      1  2004    12502      38276       2481
# 2004-02-01  American Eagle      2  2004     8977      35762        886
# 2004-03-01  American Eagle      3  2004    10289      39445       1346
# 2004-04-01  American Eagle      4  2004     8095      38982        755
# 2004-05-01  American Eagle      5  2004    10618      40422       2206
# ...                    ...    ...   ...      ...        ...        ...
# 2010-08-01          United      8  2010    14099      30637        344
# 2010-09-01          United      9  2010     9435      28072        161
# 2010-10-01          United     10  2010     9565      29144        140
# 2010-11-01          United     11  2010     8597      27318        104
# 2010-12-01          United     12  2010    14415      27619        599
#
#             Enplaned
# Date
# 2004-01-01    992360
# 2004-02-01   1060618
# 2004-03-01   1227469
# 2004-04-01   1234451
# 2004-05-01   1267581
# ...              ...
# 2010-08-01   4263211
# 2010-09-01   3679517
# 2010-10-01   3952549
# 2010-11-01   3573268
# 2010-12-01   3493643
#
# [252 rows x 7 columns]>

# %%
df['Airline'].value_counts()
# Out:
# Airline
# American Eagle    84
# Hawaiian          84
# United            84
# Name: count, dtype: int64

# %% [markdown]
# Feature engineering

# %% [raw]
#  To adjust for company's size we calculate the rate of baggage complaints

# %%
df['Baggage %'] = 100* df['Baggage']/df['Enplaned']

# %%
df
# Out:
#                    Airline  Month  Year  Baggage  Scheduled  Cancelled  \
# Date
# 2004-01-01  American Eagle      1  2004    12502      38276       2481
# 2004-02-01  American Eagle      2  2004     8977      35762        886
# 2004-03-01  American Eagle      3  2004    10289      39445       1346
# 2004-04-01  American Eagle      4  2004     8095      38982        755
# 2004-05-01  American Eagle      5  2004    10618      40422       2206
# ...                    ...    ...   ...      ...        ...        ...
# 2010-08-01          United      8  2010    14099      30637        344
# 2010-09-01          United      9  2010     9435      28072        161
# 2010-10-01          United     10  2010     9565      29144        140
# 2010-11-01          United     11  2010     8597      27318        104
# 2010-12-01          United     12  2010    14415      27619        599
#
#             Enplaned  Baggage %
# Date
# 2004-01-01    992360   1.259825
# 2004-02-01   1060618   0.846393
# 2004-03-01   1227469   0.838229
# 2004-04-01   1234451   0.655757
# 2004-05-01   1267581   0.837659
# ...              ...        ...
# 2010-08-01   4263211   0.330713
# 2010-09-01   3679517   0.256420
# 2010-10-01   3952549   0.241996
# 2010-11-01   3573268   0.240592
# 2010-12-01   3493643   0.412607
#
# [252 rows x 8 columns]

# %% [raw]
# Creating dataframes for each company, setting index frequency and checking datasets

# %%
grouped = df.groupby(df.Airline)
dfAmerican = grouped.get_group("American Eagle")
dfAmerican
# Out:
#                    Airline  Month  Year  Baggage  Scheduled  Cancelled  \
# Date
# 2004-01-01  American Eagle      1  2004    12502      38276       2481
# 2004-02-01  American Eagle      2  2004     8977      35762        886
# 2004-03-01  American Eagle      3  2004    10289      39445       1346
# 2004-04-01  American Eagle      4  2004     8095      38982        755
# 2004-05-01  American Eagle      5  2004    10618      40422       2206
# ...                    ...    ...   ...      ...        ...        ...
# 2010-08-01  American Eagle      8  2010     9583      37697        538
# 2010-09-01  American Eagle      9  2010     8324      36524        630
# 2010-10-01  American Eagle     10  2010     8498      37766        542
# 2010-11-01  American Eagle     11  2010     8067      35778        335
# 2010-12-01  American Eagle     12  2010    11526      36605       2004
#
#             Enplaned  Baggage %
# Date
# 2004-01-01    992360   1.259825
# 2004-02-01   1060618   0.846393
# 2004-03-01   1227469   0.838229
# 2004-04-01   1234451   0.655757
# 2004-05-01   1267581   0.837659
# ...              ...        ...
# 2010-08-01   1388344   0.690247
# 2010-09-01   1336997   0.622589
# 2010-10-01   1462312   0.581135
# 2010-11-01   1346419   0.599145
# 2010-12-01   1298950   0.887332
#
# [84 rows x 8 columns]

# %%
dfHawaiian = grouped.get_group("Hawaiian")
dfHawaiian
# Out:
#              Airline  Month  Year  Baggage  Scheduled  Cancelled  Enplaned  \
# Date
# 2004-01-01  Hawaiian      1  2004     1717       3879         28    461353
# 2004-02-01  Hawaiian      2  2004     1599       3743         34    446091
# 2004-03-01  Hawaiian      3  2004     1327       4052         16    501722
# 2004-04-01  Hawaiian      4  2004     1350       3918          8    466457
# 2004-05-01  Hawaiian      5  2004     1304       3976          8    460080
# ...              ...    ...   ...      ...        ...        ...       ...
# 2010-08-01  Hawaiian      8  2010     1283       6349          4    798306
# 2010-09-01  Hawaiian      9  2010     1912       5484          2    664689
# 2010-10-01  Hawaiian     10  2010     2265       5529          1    708640
# 2010-11-01  Hawaiian     11  2010     2020       5328          5    678689
# 2010-12-01  Hawaiian     12  2010     2705       5578         15    715961
#
#             Baggage %
# Date
# 2004-01-01   0.372166
# 2004-02-01   0.358447
# 2004-03-01   0.264489
# 2004-04-01   0.289416
# 2004-05-01   0.283429
# ...               ...
# 2010-08-01   0.160715
# 2010-09-01   0.287653
# 2010-10-01   0.319626
# 2010-11-01   0.297633
# 2010-12-01   0.377814
#
# [84 rows x 8 columns]

# %%
dfUnited = grouped.get_group("United")
dfUnited
# Out:
#            Airline  Month  Year  Baggage  Scheduled  Cancelled  Enplaned  \
# Date
# 2004-01-01  United      1  2004    25015      45809       1017   4434315
# 2004-02-01  United      2  2004    16660      42675        312   4458657
# 2004-03-01  United      3  2004    19318      46512        321   5302929
# 2004-04-01  United      4  2004    15638      45309        162   5288871
# 2004-05-01  United      5  2004    19302      46630        652   5408451
# ...            ...    ...   ...      ...        ...        ...       ...
# 2010-08-01  United      8  2010    14099      30637        344   4263211
# 2010-09-01  United      9  2010     9435      28072        161   3679517
# 2010-10-01  United     10  2010     9565      29144        140   3952549
# 2010-11-01  United     11  2010     8597      27318        104   3573268
# 2010-12-01  United     12  2010    14415      27619        599   3493643
#
#             Baggage %
# Date
# 2004-01-01   0.564123
# 2004-02-01   0.373655
# 2004-03-01   0.364289
# 2004-04-01   0.295677
# 2004-05-01   0.356886
# ...               ...
# 2010-08-01   0.330713
# 2010-09-01   0.256420
# 2010-10-01   0.241996
# 2010-11-01   0.240592
# 2010-12-01   0.412607
#
# [84 rows x 8 columns]

# %%
dfAmerican.index.freq = 'MS' #Month Start frequency
print(len(dfAmerican))
print(dfAmerican.head())
# Out:
# 84
#                    Airline  Month  Year  Baggage  Scheduled  Cancelled  \
# Date
# 2004-01-01  American Eagle      1  2004    12502      38276       2481
# 2004-02-01  American Eagle      2  2004     8977      35762        886
# 2004-03-01  American Eagle      3  2004    10289      39445       1346
# 2004-04-01  American Eagle      4  2004     8095      38982        755
# 2004-05-01  American Eagle      5  2004    10618      40422       2206
#
#             Enplaned  Baggage %
# Date
# 2004-01-01    992360   1.259825
# 2004-02-01   1060618   0.846393
# 2004-03-01   1227469   0.838229
# 2004-04-01   1234451   0.655757
# 2004-05-01   1267581   0.837659

# %%
dfHawaiian.index.freq = 'MS'
print(len(dfHawaiian))
print(dfHawaiian.head())
# Out:
# 84
#              Airline  Month  Year  Baggage  Scheduled  Cancelled  Enplaned  \
# Date
# 2004-01-01  Hawaiian      1  2004     1717       3879         28    461353
# 2004-02-01  Hawaiian      2  2004     1599       3743         34    446091
# 2004-03-01  Hawaiian      3  2004     1327       4052         16    501722
# 2004-04-01  Hawaiian      4  2004     1350       3918          8    466457
# 2004-05-01  Hawaiian      5  2004     1304       3976          8    460080
#
#             Baggage %
# Date
# 2004-01-01   0.372166
# 2004-02-01   0.358447
# 2004-03-01   0.264489
# 2004-04-01   0.289416
# 2004-05-01   0.283429

# %%
dfUnited.index.freq = 'MS'
print(len(dfUnited))
print(dfUnited.head())
# Out:
# 84
#            Airline  Month  Year  Baggage  Scheduled  Cancelled  Enplaned  \
# Date
# 2004-01-01  United      1  2004    25015      45809       1017   4434315
# 2004-02-01  United      2  2004    16660      42675        312   4458657
# 2004-03-01  United      3  2004    19318      46512        321   5302929
# 2004-04-01  United      4  2004    15638      45309        162   5288871
# 2004-05-01  United      5  2004    19302      46630        652   5408451
#
#             Baggage %
# Date
# 2004-01-01   0.564123
# 2004-02-01   0.373655
# 2004-03-01   0.364289
# 2004-04-01   0.295677
# 2004-05-01   0.356886

# %% [markdown]
# EDA

# %% [raw]
# We start by exploring baggage complaints over time.

# %%
fig = px.line(df, y="Baggage", color="Airline", color_discrete_sequence=px.colors.qualitative.Pastel)
fig.update_layout(plot_bgcolor='white')
fig.update_yaxes(
    mirror=True,
    ticks='outside',
    showline=True,
    linecolor='black',
    gridcolor='lightgrey',
    title=''
)
fig.show()

# %% [raw]
# United Airlines has the most complaints about mishandled baggage in almost all of the months in the data set; Hawaiian Airlines has the fewest number of complaints in all months. Do we conclude, then, that United Airlines has the “worst record” for mishandled baggage and Hawaiian, the best?

# %%
newframe = df.groupby('Airline').describe()[['Scheduled', 'Enplaned']]
newframe = newframe.drop(['count','std','min','25%','50%','75%','max'], axis = 1, level = 1)
newframe = newframe.round(decimals=2)
newframe
# Out:
#                Scheduled    Enplaned
#                     mean        mean
# Airline
# American Eagle  41314.05  1396725.55
# Hawaiian         4844.68   594174.17
# United          38225.30  4620712.26

# %% [raw]
# United Airlines is a much bigger airline, which shows the average number of scheduled flights and enplaned passengers by airline. United handles more than three times the number of passengers than American Eagle on average, and almost eight times more than Hawaiian. Thus, United has more opportunities to mishandle luggage because it handles more luggage – it’s simply a much bigger airline.

# %% [raw]
# So we compare the records of the three airlines using Baggage %.

# %%
newframe = df.groupby('Airline').describe()['Baggage %']
newframe = newframe.drop(['count','std','min','25%','50%','75%','max'], axis = 1)
newframe = newframe.round(decimals=3)
newframe
# Out:
#                  mean
# Airline
# American Eagle  1.033
# Hawaiian        0.277
# United          0.464

# %% [raw]
# We see that American Eagle has the highest rate of baggage complaints when adjusted for number of enplaned passengers.
#
# Plotting the Baggage % on a time series plot allows us to see changes over time.

# %%
fig = px.line(df, y="Baggage %", color="Airline", color_discrete_sequence=px.colors.qualitative.Pastel)
fig.update_layout(plot_bgcolor='white')
fig.update_yaxes(
    mirror=True,
    ticks='outside',
    showline=True,
    linecolor='black',
    gridcolor='lightgrey',
    title=''
)
fig.show()

# %% [raw]
# So we see that baggage complaint rates from American Eagle and United passengers increased through 2006 and began declining thereafter

# %% [raw]
# The time series for Hawaiian passengers is relatively flat compared to American Eagle and United, so it’s difficult to detect a pattern over time.

# %%
fig = px.line(df, y="Baggage %", color="Airline", facet_col="Airline", color_discrete_sequence=px.colors.qualitative.Pastel)
fig.update_layout(plot_bgcolor='white')
fig.update_yaxes(
    mirror=True,
    ticks=None,
    showline=True,
    linecolor='black',
    gridcolor='lightgrey',
    title='',
    matches=None,
    visible=False
)
fig.show()

# %% [raw]
# We isolated the data for the Hawaiian flights. Complaint rates for Hawaiian passengers began to drop in the summer of 2008 until fall of 2010, after which the rate of complaints returned to historical levels.

# %% [raw]
# The pattern of spikes and dips indicates that changes in the rate of baggage complaints may have a seasonal component.

# %%
Baggage_mean = df.groupby(["Airline","Month"]).mean(['Baggage %'])
Baggage_mean = Baggage_mean.reset_index()
Baggage_mean
# Out:
#            Airline  Month    Year       Baggage     Scheduled    Cancelled  \
# 0   American Eagle      1  2007.0  15729.285714  41054.571429  2119.000000
# 1   American Eagle      2  2007.0  12702.285714  37579.000000  1735.571429
# 2   American Eagle      3  2007.0  14742.857143  41436.142857  1448.857143
# 3   American Eagle      4  2007.0  13050.285714  40834.142857  1030.000000
# 4   American Eagle      5  2007.0  13796.428571  42490.714286  1294.428571
# 5   American Eagle      6  2007.0  16901.142857  41790.142857  1647.285714
# 6   American Eagle      7  2007.0  16621.285714  43182.571429  1486.714286
# 7   American Eagle      8  2007.0  16106.714286  43340.571429  1225.000000
# 8   American Eagle      9  2007.0  12196.285714  41193.714286   994.285714
# 9   American Eagle     10  2007.0  13051.428571  42135.285714   926.571429
# 10  American Eagle     11  2007.0  11380.142857  39789.142857   800.857143
# 11  American Eagle     12  2007.0  19152.285714  40942.571429  2268.571429
# 12        Hawaiian      1  2007.0   1550.571429   4750.714286    18.571429
# 13        Hawaiian      2  2007.0   1417.857143   4336.285714    13.000000
# 14        Hawaiian      3  2007.0   1608.857143   4728.000000    11.000000
# 15        Hawaiian      4  2007.0   1518.285714   4601.142857    12.285714
# 16        Hawaiian      5  2007.0   1547.000000   4736.285714     9.714286
# 17        Hawaiian      6  2007.0   1750.714286   4974.857143    12.285714
# 18        Hawaiian      7  2007.0   1873.285714   5336.000000    30.142857
# 19        Hawaiian      8  2007.0   1677.000000   5313.857143    22.285714
# 20        Hawaiian      9  2007.0   1486.714286   4719.285714    12.142857
# 21        Hawaiian     10  2007.0   1655.000000   4882.428571    17.285714
# 22        Hawaiian     11  2007.0   1562.571429   4771.285714    20.857143
# 23        Hawaiian     12  2007.0   1810.857143   4986.000000    35.142857
# 24          United      1  2007.0  25566.857143  38038.571429   903.428571
# 25          United      2  2007.0  19484.857143  35425.000000   956.571429
# 26          United      3  2007.0  21821.000000  39601.428571   647.142857
# 27          United      4  2007.0  17316.857143  37783.428571   563.142857
# 28          United      5  2007.0  19292.285714  38920.714286   513.714286
# 29          United      6  2007.0  25294.857143  39196.571429   713.571429
# 30          United      7  2007.0  24433.142857  40512.000000   762.142857
# 31          United      8  2007.0  25790.857143  40676.571429   657.000000
# 32          United      9  2007.0  17253.000000  38189.857143   474.714286
# 33          United     10  2007.0  18522.571429  38119.285714   441.857143
# 34          United     11  2007.0  15491.142857  35484.428571   302.571429
# 35          United     12  2007.0  28929.714286  36755.714286  1207.714286
#
#         Enplaned  Baggage %
# 0   1.197401e+06   1.293443
# 1   1.175794e+06   1.057946
# 2   1.401312e+06   1.035596
# 3   1.385810e+06   0.924347
# 4   1.487572e+06   0.911445
# 5   1.517617e+06   1.096029
# 6   1.548464e+06   1.055409
# 7   1.485647e+06   1.060192
# 8   1.371100e+06   0.870111
# 9   1.483653e+06   0.864230
# 10  1.370887e+06   0.813635
# 11  1.335451e+06   1.413701
# 12  5.485251e+05   0.289456
# 13  5.309200e+05   0.274194
# 14  5.988654e+05   0.277191
# 15  5.825661e+05   0.264787
# 16  6.023691e+05   0.258232
# 17  6.182286e+05   0.288650
# 18  6.664004e+05   0.286178
# 19  6.507813e+05   0.263623
# 20  5.616397e+05   0.266027
# 21  5.970479e+05   0.279291
# 22  5.784027e+05   0.271623
# 23  5.943436e+05   0.306501
# 24  4.146930e+06   0.610340
# 25  3.976146e+06   0.485182
# 26  4.859829e+06   0.444631
# 27  4.664194e+06   0.368128
# 28  4.816715e+06   0.396882
# 29  5.063003e+06   0.498733
# 30  5.221785e+06   0.463373
# 31  5.146224e+06   0.496691
# 32  4.356700e+06   0.390465
# 33  4.668132e+06   0.390272
# 34  4.241678e+06   0.357237
# 35  4.287211e+06   0.667244

# %%
fig = px.line(Baggage_mean, x='Month', y='Baggage %', color="Airline", facet_col="Airline", color_discrete_sequence=px.colors.qualitative.Pastel)
fig.update_layout(plot_bgcolor='white')
fig.update_yaxes(
    mirror=True,
    ticks=None,
    showline=True,
    linecolor='black',
    gridcolor='lightgrey',
    title='',
    matches=None,
    visible=False
)
fig.update_xaxes(
    dtick = 1
)
fig.show()

# %% [raw]
# We plotted the average Baggage % by month for the three airlines to investigate this further. \ Average rates are highest in December and January and in the summer months, and lowest in the spring and late fall. Interestingly, all three airlines seem to follow the same general pattern.

# %%
Baggage_mean = df.groupby(["Date"]).mean(['Baggage'])
Baggage_mean = Baggage_mean.drop(['Month','Year','Scheduled','Cancelled','Enplaned','Baggage %'], axis = 1)
Baggage_mean
# Out:
#                  Baggage
# Date
# 2004-01-01  13078.000000
# 2004-02-01   9078.666667
# 2004-03-01  10311.333333
# 2004-04-01   8361.000000
# 2004-05-01  10408.000000
# ...                  ...
# 2010-08-01   8321.666667
# 2010-09-01   6557.000000
# 2010-10-01   6776.000000
# 2010-11-01   6228.000000
# 2010-12-01   9548.666667
#
# [84 rows x 1 columns]

# %%
def plot_seasonal_decompose(result:DecomposeResult, dates:pd.Series=None, title:str="Seasonal Decomposition"):
    x_values = dates if dates is not None else np.arange(len(result.observed))
    cols = px.colors.qualitative.Pastel    
    return (
        make_subplots(
            rows=4,
            cols=1,
            subplot_titles=["Observed", "Trend", "Seasonal", "Residuals"],
        )
        .add_trace(
            go.Scatter(x=x_values, y=result.observed, mode="lines", name='Observed', marker=dict(color=cols[0])),
            row=1,
            col=1,
        )
        .add_trace(
            go.Scatter(x=x_values, y=result.trend, mode="lines", name='Trend', marker=dict(color=cols[1])),
            row=2,
            col=1,
        )
        .add_trace(
            go.Scatter(x=x_values, y=result.seasonal, mode="lines", name='Seasonal', marker=dict(color=cols[2])),
            row=3,
            col=1,
        )
        .add_trace(
            go.Scatter(x=x_values, y=result.resid, mode="lines", name='Residual', marker=dict(color=cols[3])),
            row=4,
            col=1,
        )
        .update_layout(
            height=900, title=f'<b>{title}</b>', margin={'t':100}, title_x=0.5, showlegend=False
        )
    )

# %%
decomposition = seasonal_decompose(Baggage_mean['Baggage'], model='additive', period=12)
fig = plot_seasonal_decompose(decomposition, dates=Baggage_mean.index)

fig.update_layout(plot_bgcolor='white')
fig.update_yaxes(
    mirror=True,
    ticks='outside',
    showline=True,
    linecolor='black',
    gridcolor='lightgrey',
    title=''
)

fig.show()

# %% [markdown]
# SARIMA Model

# %% [raw]
# Obtaining recommended orders

# %%
auto_arima(Baggage_mean['Baggage'], seasonal=True, m=12).summary()
# m=12 because we have Monthly data
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                   84
# Model:             SARIMAX(3, 1, 2)x(1, 0, [1], 12)   Log Likelihood                -755.119
# Date:                              Sun, 28 Jul 2024   AIC                           1528.237
# Time:                                      15:30:37   BIC                           1550.007
# Sample:                                  01-01-2004   HQIC                          1536.983
#                                        - 12-01-2010
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     94.0393    131.342      0.716      0.474    -163.387     351.466
# ar.L1          0.4298      0.286      1.501      0.133      -0.131       0.991
# ar.L2         -0.6793      0.191     -3.559      0.000      -1.053      -0.305
# ar.L3         -0.2344      0.163     -1.437      0.151      -0.554       0.085
# ma.L1         -0.6644      0.275     -2.412      0.016      -1.204      -0.125
# ma.L2          0.6658      0.244      2.729      0.006       0.188       1.144
# ar.S.L12       0.7893      0.138      5.734      0.000       0.519       1.059
# ma.S.L12      -0.3328      0.204     -1.632      0.103      -0.732       0.067
# sigma2      4.662e+06      0.001   5.67e+09      0.000    4.66e+06    4.66e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.71   Jarque-Bera (JB):                11.52
# Prob(Q):                              0.40   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.27   Skew:                             0.11
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.81
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.39e+26. Standard errors may be unstable.
# """

# %% [raw]
# We might use the ARIMA Order (3, 1, 2) combined with the Seasonal Order (1, 0, [1], 12) as we have the lowest AIC value considering those orders.

# %% [raw]
# Splitting the data into train and test sets

# %% [raw]
# One year (i.e. 12 records) for testing

# %%
train = Baggage_mean.iloc[:len(Baggage_mean)-12]
test = Baggage_mean.iloc[len(Baggage_mean)-12:]

# %% [raw]
# Fit a SARIMAX(3, 1, 2)(1, 0, [1], 12) model to the training set

# %%
model = SARIMAX(train['Baggage'], order=(3, 1, 2), seasonal_order=(1, 0, [1], 12))
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                              Baggage   No. Observations:                   72
# Model:             SARIMAX(3, 1, 2)x(1, 0, [1], 12)   Log Likelihood                -651.568
# Date:                              Sun, 28 Jul 2024   AIC                           1319.135
# Time:                                      15:31:56   BIC                           1337.237
# Sample:                                  01-01-2004   HQIC                          1326.333
#                                        - 12-01-2009
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5277      0.271      1.944      0.052      -0.004       1.060
# ar.L2         -0.7006      0.187     -3.747      0.000      -1.067      -0.334
# ar.L3         -0.2050      0.186     -1.102      0.270      -0.570       0.160
# ma.L1         -0.7674      0.233     -3.294      0.001      -1.224      -0.311
# ma.L2          0.6998      0.217      3.227      0.001       0.275       1.125
# ar.S.L12       0.9718      0.057     17.015      0.000       0.860       1.084
# ma.S.L12      -0.7718      0.197     -3.914      0.000      -1.158      -0.385
# sigma2      4.522e+06   2.95e-08   1.53e+14      0.000    4.52e+06    4.52e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.32   Jarque-Bera (JB):                 3.85
# Prob(Q):                              0.25   Prob(JB):                         0.15
# Heteroskedasticity (H):               0.36   Skew:                             0.35
# Prob(H) (two-sided):                  0.02   Kurtosis:                         3.90
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number  1e+30. Standard errors may be unstable.
# """

# %% [raw]
# Obtaining predicted values

# %%
start = len(train)
end = len(train) + len(test) - 1

# %%
predictions = results.predict(start, end, typ='levels').rename('SARIMA Test Predictions')

# %% [raw]
# Plotting Predictions X Known Values

# %%
cols = px.colors.qualitative.Pastel
fig = go.Figure()
fig.add_trace(go.Scatter(y=test['Baggage'],
                    mode='lines',
                    name='Real Values',
                    marker=dict(color=cols[0])
                        ))
fig.add_trace(go.Scatter(y=predictions,
                    mode='lines',
                    name='SARIMA Test Predictions',
                    marker=dict(color=cols[1])
                        ))
fig.update_layout(plot_bgcolor='white')
fig.update_yaxes(
    mirror=True,
    ticks='outside',
    showline=True,
    linecolor='black',
    gridcolor='lightgrey',
    title=''
)
fig.update_xaxes(
    dtick = 1
)
fig.show()

# %% [raw]
# Evaluating the Model using RMSE

# %%
error = rmse(test['Baggage'], predictions)
print(f'RMSE Error: {error}')
# Out:
# RMSE Error: 1228.4281189041212

# %%
Baggage_mean.describe()
# Out:
#             Baggage
# count     84.000000
# mean   12613.507937
# std     4396.642525
# min     6011.666667
# 25%     9032.416667
# 50%    12344.166667
# 75%    15366.666667
# max    23763.666667

# %% [raw]
# Comparision with the Standard Deviation and Mean shows us that the RMSE Error is insignificant.

# %% [raw]
# Retraining the model on the full data and forecasting one year into the future

# %%
model = SARIMAX(Baggage_mean['Baggage'], order=(3, 1, 2), seasonal_order=(1, 0, [1], 12))
results = model.fit()
forecast = results.predict(start=len(Baggage_mean), end=len(Baggage_mean)+11, type='levels').rename('SARIMA Forecast')

# %%
cols = px.colors.qualitative.Pastel
fig = go.Figure()
fig.add_trace(go.Scatter(x=Baggage_mean.index, y=Baggage_mean['Baggage'],
                    mode='lines',
                    name='Real Values',
                    marker=dict(color=cols[0])
                        ))
fig.add_trace(go.Scatter(x=forecast.index, y=forecast,
                    mode='lines',
                    name='SARIMA Test Predictions',
                    marker=dict(color=cols[1])
                        ))
fig.update_layout(plot_bgcolor='white')
fig.update_yaxes(
    mirror=True,
    ticks='outside',
    showline=True,
    linecolor='black',
    gridcolor='lightgrey',
    title=''
)

fig.show()

# %%
forecast
# Out:
# 2011-01-01    7736.494810
# 2011-02-01    6272.192232
# 2011-03-01    7179.032655
# 2011-04-01    6128.635374
# 2011-05-01    6380.768479
# 2011-06-01    7817.167379
# 2011-07-01    7236.854285
# 2011-08-01    7322.662270
# 2011-09-01    5487.697411
# 2011-10-01    5815.485950
# 2011-11-01    4953.721797
# 2011-12-01    8024.578678
# Freq: MS, Name: SARIMA Forecast, dtype: float64

# %% [raw]
# Zooming In - 2009 to 2011 and One-Year Predictions

# %%
cols = px.colors.qualitative.Pastel
fig = go.Figure()
fig.add_trace(go.Scatter(x=Baggage_mean.index[-48:], y=Baggage_mean['Baggage'][-48:],
                    mode='lines',
                    name='Real Values',
                    marker=dict(color=cols[0])
                        ))
fig.add_trace(go.Scatter(x=forecast.index, y=forecast,
                    mode='lines',
                    name='SARIMA Test Predictions',
                    marker=dict(color=cols[1])
                        ))
fig.update_layout(plot_bgcolor='white')
fig.update_yaxes(
    mirror=True,
    ticks='outside',
    showline=True,
    linecolor='black',
    gridcolor='lightgrey',
    title=''
)

fig.show()

# %% [markdown]
# Conclusions

# %% [raw]
# United Airlines is a much bigger airline, which shows the average number of scheduled flights and enplaned passengers by airline. United handles more than three times the number of passengers than American Eagle on average, and almost eight times more than Hawaiian. Thus, United has more opportunities to mishandle luggage because it handles more luggage – it’s simply a much bigger airline.
#
# Complaint rates for Hawaiian passengers began to drop in the summer of 2008 until fall of 2010, after which the rate of complaints returned to historical levels.
#
# Average rates are highest in December and January and in the summer months, and lowest in the spring and late fall. Interestingly, all three airlines seem to follow the same general pattern.
#
# The data set provided did not have information on flight destinations, so we are not able to investigate whether destination is related to baggage issues.
#
# To provide a fair comparison of performance across airlines, it’s best to standardize for differences in volume. It is also important to pay close attention to units of measurement.
#
# American Eagle has the highest rate of baggage complaints when adjusted for number of enplaned passengers.
#
# Baggage complaint rates from American Eagle and United passengers increased through 2006 and began declining thereafter.
#
# Managers at American Eagle should note the relatively high rate of baggage complaints and consider costs and benefits of improvements.
#
# All three airlines should anticipate high rates of baggage complaints in January, February and the summer months and should plan accordingly.
